# %%
#Importing necessary Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
#Reading the dataset
df=pd.read_csv('movies.csv')
df.head()
# Out:
#                     rotten_tomatoes_link  \
# 0                              m/0814255
# 1                              m/0878835
# 2                                   m/10
# 3                 m/1000013-12_angry_men
# 4  m/1000079-20000_leagues_under_the_sea
#
#                                          movie_title  \
# 0  Percy Jackson & the Olympians: The Lightning T...
# 1                                        Please Give
# 2                                                 10
# 3                    12 Angry Men (Twelve Angry Men)
# 4                       20,000 Leagues Under The Sea
#
#                                           movie_info  \
# 0  Always trouble-prone, the life of teenager Per...
# 1  Kate (Catherine Keener) and her husband Alex (...
# 2  A successful, middle-aged Hollywood songwriter...
# 3  Following the closing arguments in a murder tr...
# 4  In 1866, Professor Pierre M. Aronnax (Paul Luk...
#
#                                    critics_consensus content_rating  \
# 0  Though it may seem like just another Harry Pot...             PG
# 1  Nicole Holofcener's newest might seem slight i...              R
# 2  Blake Edwards' bawdy comedy may not score a pe...              R
# 3  Sidney Lumet's feature debut is a superbly wri...             NR
# 4  One of Disney's finest live-action adventures,...              G
#
#                                               genres          directors  \
# 0  Action & Adventure, Comedy, Drama, Science Fic...     Chris Columbus
# 1                                             Comedy  Nicole Holofcener
# 2                                    Comedy, Romance      Blake Edwards
# 3                                    Classics, Drama       Sidney Lumet
# 4           Action & Adventure, Drama, Kids & Family  Richard Fleischer
#
#                                       authors  \
# 0  Craig Titley, Chris Columbus, Rick Riordan
# 1                           Nicole Holofcener
# 2                               Blake Edwards
# 3                               Reginald Rose
# 4                                 Earl Felton
#
#                                               actors original_release_date  \
# 0  Logan Lerman, Brandon T. Jackson, Alexandra Da...            2010-02-12
# 1  Catherine Keener, Amanda Peet, Oliver Platt, R...            2010-04-30
# 2  Dudley Moore, Bo Derek, Julie Andrews, Robert ...            1979-10-05
# 3  Martin Balsam, John Fiedler, Lee J. Cobb, E.G....            1957-04-13
# 4  James Mason, Kirk Douglas, Paul Lukas, Peter L...            1954-01-01
#
#    ...      production_company  tomatometer_status tomatometer_rating  \
# 0  ...        20th Century Fox              Rotten               49.0
# 1  ...  Sony Pictures Classics     Certified-Fresh               87.0
# 2  ...             Waner Bros.               Fresh               67.0
# 3  ...    Criterion Collection     Certified-Fresh              100.0
# 4  ...                  Disney               Fresh               89.0
#
#   tomatometer_count  audience_status  audience_rating audience_count  \
# 0             149.0          Spilled             53.0       254421.0
# 1             142.0          Upright             64.0        11574.0
# 2              24.0          Spilled             53.0        14684.0
# 3              54.0          Upright             97.0       105386.0
# 4              27.0          Upright             74.0        68918.0
#
#    tomatometer_top_critics_count  tomatometer_fresh_critics_count  \
# 0                             43                               73
# 1                             44                              123
# 2                              2                               16
# 3                              6                               54
# 4                              5                               24
#
#    tomatometer_rotten_critics_count
# 0                                76
# 1                                19
# 2                                 8
# 3                                 0
# 4                                 3
#
# [5 rows x 22 columns]

# %%
#Categorising the target varible 
bins = [ 0,60,80, 100]
labels = ['FLOP', 'AVG', 'HIT']
df['binned'] = pd.cut(df['tomatometer_rating'], bins=bins, labels=labels)

# %%
df.groupby(['binned']).size().plot(kind="bar",fontsize=14)
plt.xlabel('Categories')
plt.ylabel('Number of Movies')
plt.title('Categorization of Movies')
# Out:
# Text(0.5, 1.0, 'Categorization of Movies')

# %%
#Checking the new column
df.head(5)
# Out:
#                     rotten_tomatoes_link  \
# 0                              m/0814255
# 1                              m/0878835
# 2                                   m/10
# 3                 m/1000013-12_angry_men
# 4  m/1000079-20000_leagues_under_the_sea
#
#                                          movie_title  \
# 0  Percy Jackson & the Olympians: The Lightning T...
# 1                                        Please Give
# 2                                                 10
# 3                    12 Angry Men (Twelve Angry Men)
# 4                       20,000 Leagues Under The Sea
#
#                                           movie_info  \
# 0  Always trouble-prone, the life of teenager Per...
# 1  Kate (Catherine Keener) and her husband Alex (...
# 2  A successful, middle-aged Hollywood songwriter...
# 3  Following the closing arguments in a murder tr...
# 4  In 1866, Professor Pierre M. Aronnax (Paul Luk...
#
#                                    critics_consensus content_rating  \
# 0  Though it may seem like just another Harry Pot...             PG
# 1  Nicole Holofcener's newest might seem slight i...              R
# 2  Blake Edwards' bawdy comedy may not score a pe...              R
# 3  Sidney Lumet's feature debut is a superbly wri...             NR
# 4  One of Disney's finest live-action adventures,...              G
#
#                                               genres          directors  \
# 0  Action & Adventure, Comedy, Drama, Science Fic...     Chris Columbus
# 1                                             Comedy  Nicole Holofcener
# 2                                    Comedy, Romance      Blake Edwards
# 3                                    Classics, Drama       Sidney Lumet
# 4           Action & Adventure, Drama, Kids & Family  Richard Fleischer
#
#                                       authors  \
# 0  Craig Titley, Chris Columbus, Rick Riordan
# 1                           Nicole Holofcener
# 2                               Blake Edwards
# 3                               Reginald Rose
# 4                                 Earl Felton
#
#                                               actors original_release_date  \
# 0  Logan Lerman, Brandon T. Jackson, Alexandra Da...            2010-02-12
# 1  Catherine Keener, Amanda Peet, Oliver Platt, R...            2010-04-30
# 2  Dudley Moore, Bo Derek, Julie Andrews, Robert ...            1979-10-05
# 3  Martin Balsam, John Fiedler, Lee J. Cobb, E.G....            1957-04-13
# 4  James Mason, Kirk Douglas, Paul Lukas, Peter L...            1954-01-01
#
#    ... tomatometer_status  tomatometer_rating tomatometer_count  \
# 0  ...             Rotten                49.0             149.0
# 1  ...    Certified-Fresh                87.0             142.0
# 2  ...              Fresh                67.0              24.0
# 3  ...    Certified-Fresh               100.0              54.0
# 4  ...              Fresh                89.0              27.0
#
#   audience_status  audience_rating  audience_count  \
# 0         Spilled             53.0        254421.0
# 1         Upright             64.0         11574.0
# 2         Spilled             53.0         14684.0
# 3         Upright             97.0        105386.0
# 4         Upright             74.0         68918.0
#
#   tomatometer_top_critics_count  tomatometer_fresh_critics_count  \
# 0                            43                               73
# 1                            44                              123
# 2                             2                               16
# 3                             6                               54
# 4                             5                               24
#
#    tomatometer_rotten_critics_count  binned
# 0                                76    FLOP
# 1                                19     HIT
# 2                                 8     AVG
# 3                                 0     HIT
# 4                                 3     HIT
#
# [5 rows x 23 columns]

# %%
#Shape of the dataset
df.shape
# Out:
# (17712, 23)

# %%
df.drop(columns=['critics_consensus'],inplace=True)

# %%
#Total null values present in each column
df.isnull().sum()
# Out:
# rotten_tomatoes_link                   0
# movie_title                            0
# movie_info                           321
# content_rating                         0
# genres                                19
# directors                            194
# authors                             1542
# actors                               352
# original_release_date               1166
# streaming_release_date               384
# runtime                              314
# production_company                   499
# tomatometer_status                    44
# tomatometer_rating                    44
# tomatometer_count                     44
# audience_status                      448
# audience_rating                      296
# audience_count                       297
# tomatometer_top_critics_count          0
# tomatometer_fresh_critics_count        0
# tomatometer_rotten_critics_count       0
# binned                               408
# dtype: int64

# %%
#Droping the samples that have missing values
df.dropna(inplace=True)

# %%
#Final shape of the data after Droping missing values
df.shape
# Out:
# (14142, 22)

# %%
#List of variables in the datset
df.columns
# Out:
# Index(['rotten_tomatoes_link', 'movie_title', 'movie_info', 'content_rating',
#        'genres', 'directors', 'authors', 'actors', 'original_release_date',
#        'streaming_release_date', 'runtime', 'production_company',
#        'tomatometer_status', 'tomatometer_rating', 'tomatometer_count',
#        'audience_status', 'audience_rating', 'audience_count',
#        'tomatometer_top_critics_count', 'tomatometer_fresh_critics_count',
#        'tomatometer_rotten_critics_count', 'binned'],
#       dtype='object')

# %%
data2 = df.copy()

# %%
sns.jointplot(x='tomatometer_fresh_critics_count',y='tomatometer_top_critics_count',data=data2,kind='scatter')

# %%
data2.groupby(['tomatometer_status']).size().plot(kind="bar",fontsize=14)
# Out:
# <AxesSubplot:xlabel='tomatometer_status'>

# %%
sns.pairplot(data2)

# %%
sns.boxplot(x="tomatometer_status", y="audience_rating", data=data2 ,palette='rainbow')
# Out:
# <AxesSubplot:xlabel='tomatometer_status', ylabel='audience_rating'>

# %%
sns.stripplot(x="content_rating", y="tomatometer_rating", data=data2 ,jitter=True,hue='audience_status',palette='Set1')
# Out:
# <AxesSubplot:xlabel='content_rating', ylabel='tomatometer_rating'>

# %%
sns.boxplot(x="content_rating", y="tomatometer_rating", hue="audience_status",data=data2, palette="coolwarm")
# Out:
# <AxesSubplot:xlabel='content_rating', ylabel='tomatometer_rating'>

# %%
#Describing the categorical data
df.describe(include='object')
# Out:
#                          rotten_tomatoes_link movie_title  \
# count                                   14142       14142
# unique                                  14142       13723
# top     m/mother_may_i_sleep_with_danger_2016      Carrie
# freq                                        1           4
#
#                                                movie_info content_rating  \
# count                                               14142          14142
# unique                                              14141              6
# top     Wisecracking mercenary Deadpool meets Russell,...              R
# freq                                                    2           5555
#
#        genres         directors      authors         actors  \
# count   14142             14142        14142          14142
# unique    984              6909        11365          14140
# top     Drama  Alfred Hitchcock  Woody Allen  Werner Herzog
# freq     1582                36           33              3
#
#        original_release_date streaming_release_date     production_company  \
# count                  14142                  14142                  14142
# unique                  5291                   2049                   2381
# top               1988-01-01             2016-08-10  Warner Bros. Pictures
# freq                      23                   1025                    480
#
#        tomatometer_status audience_status
# count               14142           14142
# unique                  3               2
# top                Rotten         Upright
# freq                 6333            7640

# %%
#original_release_date
# convert column to datetime pandas 
df['original_release_date'] = pd.to_datetime(df['original_release_date'])

# %%
df.dtypes
# Out:
# rotten_tomatoes_link                        object
# movie_title                                 object
# movie_info                                  object
# content_rating                              object
# genres                                      object
# directors                                   object
# authors                                     object
# actors                                      object
# original_release_date               datetime64[ns]
# streaming_release_date                      object
# runtime                                    float64
# production_company                          object
# tomatometer_status                          object
# tomatometer_rating                         float64
# tomatometer_count                          float64
# audience_status                             object
# audience_rating                            float64
# audience_count                             float64
# tomatometer_top_critics_count                int64
# tomatometer_fresh_critics_count              int64
# tomatometer_rotten_critics_count             int64
# binned                                    category
# dtype: object

# %%
# Filter Rows by Dates in pandas DataFrame
df2 = df[(df['original_release_date'] > "2011-01-01") & (df['original_release_date']< "2020-12-31")]

# %%
df2.head()
# Out:
#                    rotten_tomatoes_link              movie_title  \
# 98   m/10008601-fireflies_in_the_garden  Fireflies in the Garden
# 157                   m/10009274-priest                   Priest
# 191             m/1000_times_good_night   1,000 Times Good Night
# 218      m/10010694-season_of_the_witch      Season of the Witch
# 249                m/10011494-last_ride                Last Ride
#
#                                             movie_info content_rating  \
# 98   Successful novelist Michael (Ryan Reynolds) vi...              R
# 157  In a society ravaged by centuries of war betwe...          PG-13
# 191  A war-zone photojournalist's (Juliette Binoche...             NR
# 218  His faith broken by many years fighting in the...          PG-13
# 249  A young boy (Tom Russell) and his wanted fathe...          PG-13
#
#                                                 genres         directors  \
# 98                                               Drama  Dennis Lee (III)
# 157  Action & Adventure, Horror, Mystery & Suspense...     Scott Stewart
# 191                                              Drama        Erik Poppe
# 218  Action & Adventure, Drama, Mystery & Suspense,...      Dominic Sena
# 249                                              Drama      Glendyn Ivin
#
#                                            authors  \
# 98                                Dennis Lee (III)
# 157                    Scott Stewart, Cory Goodman
# 191                            Harald Rosenløw-Eeg
# 218  Bragi Schut, Jr, Bragi F. Schut, Dominic Sena
# 249                                    Mac Gudgeon
#
#                                                 actors original_release_date  \
# 98   Emily Watson, Julia Roberts, Ryan Reynolds, Wi...            2011-10-14
# 157  Paul Bettany, Maggie Q, Cam Gigandet, Lily Col...            2011-05-13
# 191  Juliette Binoche, Nikolaj Coster-Waldau, Laury...            2014-10-24
# 218  Nicolas Cage, Ron Perlman, Stephen Campbell Mo...            2011-01-07
# 249  Hugo Weaving, Tom Russell, Anita Hegh, John Br...            2012-06-29
#
#     streaming_release_date  ...  tomatometer_status tomatometer_rating  \
# 98              2014-01-09  ...              Rotten               22.0
# 157             2012-04-16  ...              Rotten               15.0
# 191             2016-08-10  ...               Fresh               71.0
# 218             2011-06-23  ...              Rotten               11.0
# 249             2016-08-10  ...               Fresh               93.0
#
#     tomatometer_count  audience_status  audience_rating audience_count  \
# 98               54.0          Spilled             45.0        45155.0
# 157             100.0          Spilled             46.0        86623.0
# 191              55.0          Upright             65.0         1884.0
# 218             124.0          Spilled             30.0        79868.0
# 249              28.0          Upright             65.0         3560.0
#
#      tomatometer_top_critics_count  tomatometer_fresh_critics_count  \
# 98                              23                               12
# 157                             18                               15
# 191                             22                               39
# 218                             30                               14
# 249                             10                               26
#
#      tomatometer_rotten_critics_count  binned
# 98                                 42    FLOP
# 157                                85    FLOP
# 191                                16     AVG
# 218                               110    FLOP
# 249                                 2     HIT
#
# [5 rows x 22 columns]

# %%
df2.to_csv("moviesv2.csv",index=False)

# %%
df2.head()
# Out:
#                    rotten_tomatoes_link              movie_title  \
# 98   m/10008601-fireflies_in_the_garden  Fireflies in the Garden
# 157                   m/10009274-priest                   Priest
# 191             m/1000_times_good_night   1,000 Times Good Night
# 218      m/10010694-season_of_the_witch      Season of the Witch
# 249                m/10011494-last_ride                Last Ride
#
#                                             movie_info content_rating  \
# 98   Successful novelist Michael (Ryan Reynolds) vi...              R
# 157  In a society ravaged by centuries of war betwe...          PG-13
# 191  A war-zone photojournalist's (Juliette Binoche...             NR
# 218  His faith broken by many years fighting in the...          PG-13
# 249  A young boy (Tom Russell) and his wanted fathe...          PG-13
#
#                                                 genres         directors  \
# 98                                               Drama  Dennis Lee (III)
# 157  Action & Adventure, Horror, Mystery & Suspense...     Scott Stewart
# 191                                              Drama        Erik Poppe
# 218  Action & Adventure, Drama, Mystery & Suspense,...      Dominic Sena
# 249                                              Drama      Glendyn Ivin
#
#                                            authors  \
# 98                                Dennis Lee (III)
# 157                    Scott Stewart, Cory Goodman
# 191                            Harald Rosenløw-Eeg
# 218  Bragi Schut, Jr, Bragi F. Schut, Dominic Sena
# 249                                    Mac Gudgeon
#
#                                                 actors original_release_date  \
# 98   Emily Watson, Julia Roberts, Ryan Reynolds, Wi...            2011-10-14
# 157  Paul Bettany, Maggie Q, Cam Gigandet, Lily Col...            2011-05-13
# 191  Juliette Binoche, Nikolaj Coster-Waldau, Laury...            2014-10-24
# 218  Nicolas Cage, Ron Perlman, Stephen Campbell Mo...            2011-01-07
# 249  Hugo Weaving, Tom Russell, Anita Hegh, John Br...            2012-06-29
#
#     streaming_release_date  ...  tomatometer_status tomatometer_rating  \
# 98              2014-01-09  ...              Rotten               22.0
# 157             2012-04-16  ...              Rotten               15.0
# 191             2016-08-10  ...               Fresh               71.0
# 218             2011-06-23  ...              Rotten               11.0
# 249             2016-08-10  ...               Fresh               93.0
#
#     tomatometer_count  audience_status  audience_rating audience_count  \
# 98               54.0          Spilled             45.0        45155.0
# 157             100.0          Spilled             46.0        86623.0
# 191              55.0          Upright             65.0         1884.0
# 218             124.0          Spilled             30.0        79868.0
# 249              28.0          Upright             65.0         3560.0
#
#      tomatometer_top_critics_count  tomatometer_fresh_critics_count  \
# 98                              23                               12
# 157                             18                               15
# 191                             22                               39
# 218                             30                               14
# 249                             10                               26
#
#      tomatometer_rotten_critics_count  binned
# 98                                 42    FLOP
# 157                                85    FLOP
# 191                                16     AVG
# 218                               110    FLOP
# 249                                 2     HIT
#
# [5 rows x 22 columns]

# %%
pokemon_games = df2.loc[df2['genres'].str.contains("Science Fiction & Fantasy", case=False)]

# %%
pokemon_games.head()
# Out:
#                 rotten_tomatoes_link          movie_title  \
# 157                m/10009274-priest               Priest
# 218   m/10010694-season_of_the_witch  Season of the Witch
# 258                  m/10011815-hole             The Hole
# 1306           m/10_cloverfield_lane  10 Cloverfield Lane
# 1704               m/1200731-robocop              RoboCop
#
#                                              movie_info content_rating  \
# 157   In a society ravaged by centuries of war betwe...          PG-13
# 218   His faith broken by many years fighting in the...          PG-13
# 258   Two brothers find a hole in the basement that ...          PG-13
# 1306  After surviving a car accident, Michelle (Mary...          PG-13
# 1704  In 2028, OmniCorp is at the center of robot te...          PG-13
#
#                                                  genres         directors  \
# 157   Action & Adventure, Horror, Mystery & Suspense...     Scott Stewart
# 218   Action & Adventure, Drama, Mystery & Suspense,...      Dominic Sena
# 258   Kids & Family, Mystery & Suspense, Science Fic...         Joe Dante
# 1306  Drama, Mystery & Suspense, Science Fiction & F...  Dan Trachtenberg
# 1704      Action & Adventure, Science Fiction & Fantasy      José Padilha
#
#                                                 authors  \
# 157                         Scott Stewart, Cory Goodman
# 218       Bragi Schut, Jr, Bragi F. Schut, Dominic Sena
# 258                                       Mark L. Smith
# 1306   Josh Campbell, Matthew Stuecken, Damien Chazelle
# 1704  Ed Neumeier, Michael Miner, Nick Schenk, José ...
#
#                                                  actors original_release_date  \
# 157   Paul Bettany, Maggie Q, Cam Gigandet, Lily Col...            2011-05-13
# 218   Nicolas Cage, Ron Perlman, Stephen Campbell Mo...            2011-01-07
# 258   Chris Massoglia, Haley Bennett, Nathan Gamble,...            2012-09-28
# 1306  Mary Elizabeth Winstead, John Goodman, John Ga...            2016-03-11
# 1704  Joel Kinnaman, Gary Oldman, Michael Keaton, Sa...            2014-02-12
#
#      streaming_release_date  ...  tomatometer_status tomatometer_rating  \
# 157              2012-04-16  ...              Rotten               15.0
# 218              2011-06-23  ...              Rotten               11.0
# 258              2016-08-08  ...               Fresh               81.0
# 1306             2016-05-31  ...     Certified-Fresh               90.0
# 1704             2016-08-12  ...              Rotten               48.0
#
#      tomatometer_count  audience_status  audience_rating audience_count  \
# 157              100.0          Spilled             46.0        86623.0
# 218              124.0          Spilled             30.0        79868.0
# 258               36.0          Spilled             46.0        14727.0
# 1306             309.0          Upright             79.0        60918.0
# 1704             219.0          Spilled             49.0       127181.0
#
#       tomatometer_top_critics_count  tomatometer_fresh_critics_count  \
# 157                              18                               15
# 218                              30                               14
# 258                               8                               29
# 1306                             52                              278
# 1704                             48                              105
#
#       tomatometer_rotten_critics_count  binned
# 157                                 85    FLOP
# 218                                110    FLOP
# 258                                  7     HIT
# 1306                                31     HIT
# 1704                               114    FLOP
#
# [5 rows x 22 columns]

# %%
#testing dataset
df3 = pokemon_games[(pokemon_games['original_release_date'] > "2019-01-01") & (df['original_release_date']< "2020-12-31")]
# Out:
# <ipython-input-61-ea393b8accf6>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df3 = pokemon_games[(pokemon_games['original_release_date'] > "2019-01-01") & (df['original_release_date']< "2020-12-31")]

# %%
df3.head()
# Out:
#      rotten_tomatoes_link        movie_title  \
# 1920            m/21_2020                2/1
# 2290  m/above_the_shadows  Above the Shadows
# 2403     m/after_we_leave     After We Leave
# 2458              m/akira              Akira
# 2887            m/archive            Archive
#
#                                              movie_info content_rating  \
# 1920  Two men, strangers to one another and living o...             NR
# 2290  Holly has faded to the point of becoming invis...             NR
# 2403  In the near future, a man struggles to find hi...             NR
# 2458  In 1988 the Japanese government drops an atomi...              R
# 2887  In 2038 a man hopes to reunite with his dead w...             NR
#
#                                                  genres        directors  \
# 1920                   Drama, Science Fiction & Fantasy      Juan Cabral
# 2290                   Drama, Science Fiction & Fantasy    Claudia Myers
# 2403                   Drama, Science Fiction & Fantasy    Aleem Hossain
# 2458  Action & Adventure, Animation, Drama, Mystery ...  Katsuhiro Ôtomo
# 2887                          Science Fiction & Fantasy    Gavin Rothery
#
#                              authors  \
# 1920                     Juan Cabral
# 2290                   Claudia Myers
# 2403                   Aleem Hossain
# 2458  Katsuhiro Ôtomo, Izo Hashimoto
# 2887                   Gavin Rothery
#
#                                                  actors original_release_date  \
# 1920  Boyd Holbrook, Song Yang, Dominique McElligott...            2020-02-07
# 2290  Olivia Thirlby, Megan Fox, Alan Ritchson, Jim ...            2019-07-19
# 2403  Brian Silverman, Clay Wilcox, Anita Leeman Tor...            2020-02-21
# 2458  Cameron Clarke, Mitsuo Iwara, Nozomu Sasaki, J...            2020-09-24
# 2887  Rhona Mitra, Theo James, Toby Jones, Stacy Mar...            2020-07-10
#
#      streaming_release_date  ...  tomatometer_status tomatometer_rating  \
# 1920             2020-02-05  ...              Rotten               56.0
# 2290             2019-07-19  ...              Rotten               57.0
# 2403             2020-02-18  ...               Fresh               83.0
# 2458             2016-11-30  ...     Certified-Fresh               90.0
# 2887             2020-07-10  ...               Fresh               71.0
#
#      tomatometer_count  audience_status  audience_rating audience_count  \
# 1920               9.0          Spilled             29.0            7.0
# 2290               7.0          Upright             76.0           29.0
# 2403               6.0          Spilled             38.0           26.0
# 2458              49.0          Upright             90.0       148559.0
# 2887              24.0          Upright             70.0          200.0
#
#       tomatometer_top_critics_count  tomatometer_fresh_critics_count  \
# 1920                              4                                5
# 2290                              3                                4
# 2403                              1                                5
# 2458                             12                               45
# 2887                              4                               17
#
#       tomatometer_rotten_critics_count  binned
# 1920                                 4    FLOP
# 2290                                 3    FLOP
# 2403                                 1     HIT
# 2458                                 5     HIT
# 2887                                 7     AVG
#
# [5 rows x 22 columns]

# %%
#training dataset
df4 = df[(df['original_release_date'] > "2011-01-01") & (df['original_release_date']< "2018-12-31")]

# %%
df4.tail()
# Out:
#       rotten_tomatoes_link  movie_title  \
# 17695         m/zombeavers   Zombeavers
# 17702           m/zoo_2018          Zoo
# 17703          m/zookeeper    Zookeeper
# 17705        m/zoolander_2  Zoolander 2
# 17708           m/zootopia     Zootopia
#
#                                               movie_info content_rating  \
# 17695  College friends find their weekend of sex and ...              R
# 17702  A 12-year old boy and his misfit friends enlis...             PG
# 17703  Kindhearted Griffin Keyes (Kevin James) is one...             PG
# 17705  Former models Derek Zoolander (Ben Stiller) an...          PG-13
# 17708  From the largest elephant to the smallest shre...             PG
#
#                                       genres  \
# 17695     Action & Adventure, Comedy, Horror
# 17702      Action & Adventure, Kids & Family
# 17703                        Comedy, Romance
# 17705                                 Comedy
# 17708  Action & Adventure, Animation, Comedy
#
#                                   directors  \
# 17695                          Jordan Rubin
# 17702                          Colin McIvor
# 17703             Frank Coraci, Walt Becker
# 17705                           Ben Stiller
# 17708  Byron Howard, Rich Moore, Jared Bush
#
#                                                  authors  \
# 17695                              Jon Kaplan, Al Kaplan
# 17702                                       Colin McIvor
# 17703  Jay Scherick, David Ronn, Nick Bakay, Rock Reu...
# 17705  Nicholas Stoller, John Hamburg, Ben Stiller, J...
# 17708                          Jared Bush, Phil Johnston
#
#                                                   actors  \
# 17695  Rachel Melvin, Cortney Palm, Lexi Atkins, Hutc...
# 17702  Art Parkinson, Penelope Wilton, Amy Huberman, ...
# 17703  Kevin James, Rosario Dawson, Ken Jeong, Leslie...
# 17705  Ben Stiller, Owen Wilson, Will Ferrell, Penelo...
# 17708  J.K. Simmons, Kristen Bell, Octavia Spencer, A...
#
#       original_release_date streaming_release_date  ...  tomatometer_status  \
# 17695            2015-03-20             2016-12-05  ...               Fresh
# 17702            2018-06-08             2018-06-10  ...               Fresh
# 17703            2011-07-08             2013-02-05  ...              Rotten
# 17705            2016-02-12             2016-12-30  ...              Rotten
# 17708            2016-03-04             2016-06-07  ...     Certified-Fresh
#
#       tomatometer_rating tomatometer_count  audience_status  audience_rating  \
# 17695               69.0              36.0          Spilled             31.0
# 17702               88.0              17.0          Upright             62.0
# 17703               14.0             132.0          Spilled             41.0
# 17705               22.0             232.0          Spilled             20.0
# 17708               98.0             291.0          Upright             92.0
#
#       audience_count  tomatometer_top_critics_count  \
# 17695         3657.0                              7
# 17702          128.0                              3
# 17703        44713.0                             36
# 17705        41745.0                             48
# 17708       101511.0                             50
#
#        tomatometer_fresh_critics_count  tomatometer_rotten_critics_count  \
# 17695                               25                                11
# 17702                               15                                 2
# 17703                               18                               114
# 17705                               51                               181
# 17708                              285                                 7
#
#        binned
# 17695     AVG
# 17702     HIT
# 17703    FLOP
# 17705    FLOP
# 17708     HIT
#
# [5 rows x 22 columns]

# %%
#Dropping df4 colums 2 columns
df4.drop(columns=['rotten_tomatoes_link','movie_title'],inplace=True)
df4.drop(columns=['original_release_date'],inplace=True)
df4.drop(columns=['streaming_release_date'],inplace=True)
df4.drop(columns=['tomatometer_status'],inplace=True)
df4.drop(columns=['tomatometer_rating'],inplace=True)
# Out:
# C:\Users\raora\anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
#Dropping df3 colums 2 columns
df3.drop(columns=['rotten_tomatoes_link','movie_title'],inplace=True)
df3.drop(columns=['original_release_date'],inplace=True)
df3.drop(columns=['streaming_release_date'],inplace=True)
df3.drop(columns=['tomatometer_status'],inplace=True)
df3.drop(columns=['tomatometer_rating'],inplace=True)

# %%
df4.shape
# Out:
# (4384, 16)

# %%
df3.shape
# Out:
# (50, 16)

# %%
#Label encoding the categorical columns for df3
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
cat_list=['movie_info', 'content_rating', 'genres', 'directors', 'authors',
       'actors',
       'production_company','audience_status']
df3[cat_list]=df3[cat_list].apply(lambda x:le.fit_transform(x))
# Out:
# C:\Users\raora\anaconda3\lib\site-packages\pandas\core\frame.py:3191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
#Label encoding the categorical columns for df4
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
cat_list=['movie_info', 'content_rating', 'genres', 'directors', 'authors',
       'actors',
       'production_company','audience_status']
df4[cat_list]=df4[cat_list].apply(lambda x:le.fit_transform(x))

# %%
df3.head()
# Out:
#       movie_info  content_rating  genres  directors  authors  actors  runtime  \
# 1920          43               0      17         29       28       4    100.0
# 2290          26               0      17         10       11      39    105.0
# 2403          31               0      17          2        2       5     82.0
# 2458          29               3       1         33       33       7    124.0
# 2887          30               0      23         19       18      41    105.0
#
#       production_company  tomatometer_count  audience_status  audience_rating  \
# 1920                  11                9.0                0             29.0
# 2290                  11                7.0                1             76.0
# 2403                  11                6.0                0             38.0
# 2458                  29               49.0                1             90.0
# 2887                  13               24.0                1             70.0
#
#       audience_count  tomatometer_top_critics_count  \
# 1920             7.0                              4
# 2290            29.0                              3
# 2403            26.0                              1
# 2458        148559.0                             12
# 2887           200.0                              4
#
#       tomatometer_fresh_critics_count  tomatometer_rotten_critics_count binned
# 1920                                5                                 4   FLOP
# 2290                                4                                 3   FLOP
# 2403                                5                                 1    HIT
# 2458                               45                                 5    HIT
# 2887                               17                                 7    AVG

# %%
df4.head()
# Out:
#      movie_info  content_rating  genres  directors  authors  actors  runtime  \
# 98         3564               5     276        849     1045    1306     98.0
# 157        2662               4      84       2806     3420    3324     87.0
# 191         880               2     276        988     1450    2314    117.0
# 218        2430               4      72        881      481    3209     95.0
# 249         942               4     276       1136     2416    1685    100.0
#
#      production_company  tomatometer_count  audience_status  audience_rating  \
# 98                  882               54.0                0             45.0
# 157                 873              100.0                0             46.0
# 191                 378               55.0                1             65.0
# 218                 823              124.0                0             30.0
# 249                 669               28.0                1             65.0
#
#      audience_count  tomatometer_top_critics_count  \
# 98          45155.0                             23
# 157         86623.0                             18
# 191          1884.0                             22
# 218         79868.0                             30
# 249          3560.0                             10
#
#      tomatometer_fresh_critics_count  tomatometer_rotten_critics_count binned
# 98                                12                                42   FLOP
# 157                               15                                85   FLOP
# 191                               39                                16    AVG
# 218                               14                               110   FLOP
# 249                               26                                 2    HIT

# %%
df5 = df4.append(df3)

# %%
#Independent Variables
X = df5.iloc[:, 0:15].values
#Dependent/Target Variable
y = df5.iloc[:, 15].values
y
# Out:
# ['FLOP', 'FLOP', 'AVG', 'FLOP', 'HIT', ..., 'AVG', 'HIT', 'FLOP', 'AVG', 'FLOP']
# Length: 4434
# Categories (3, object): ['FLOP' < 'AVG' < 'HIT']

# %%
#Spliting the data into train and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.02, random_state = 0,stratify = y)
print(X_train.shape)
print(y_train.shape)
# Out:
# (4345, 15)
# (4345,)

# %%
#Scaling the dependent variables
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
#Performing Recursive Feauture Elimation with Cross Validation
#Using Random forest for RFE-CV and logloss as scoring
from sklearn.feature_selection import RFECV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import log_loss
clf_rf=RandomForestClassifier(random_state=0)
rfecv=RFECV(estimator=clf_rf, step=1,cv=5,scoring='neg_log_loss')
rfecv=rfecv.fit(X_train,y_train)

# %%
#Optimal number of features
X_train = pd.DataFrame(X_train)
X_test = pd.DataFrame(X_test)
print('Optimal number of features :', rfecv.n_features_)
print('Best features :', X_train.columns[rfecv.support_])
# Out:
# Optimal number of features : 2
# Best features : Int64Index([13, 14], dtype='int64')

# %%
#Feauture Ranking
clf_rf = clf_rf.fit(X_train,y_train)
importances = clf_rf.feature_importances_

std = np.std([tree.feature_importances_ for tree in clf_rf.estimators_],
             axis=0)
indices = np.argsort(importances)[::-1]

# %%
#Logloss vs Number of features
import matplotlib.pyplot as plt
plt.figure()
plt.xlabel("Number of features selected")
plt.ylabel("Cross validation score of number of selected features")
plt.title("Log loss vs Number of fetures")
plt.plot(range(1, len(rfecv.grid_scores_) + 1), rfecv.grid_scores_)
plt.show()

# %%
#Selecting the Important Features
X_opt = X_train.iloc[:,X_train.columns[rfecv.support_]]
X_test = X_test.iloc[:,X_test.columns[rfecv.support_]]

# %%
#Creating anew dataframe with column names and feature importance
dset = pd.DataFrame()
data1 = df5
data1.drop(columns=['binned'],inplace=True)
dset['attr'] = data1.columns

dset['importance'] = clf_rf.feature_importances_
#Sorting with importance column
dset = dset.sort_values(by='importance', ascending=True)

#Barplot indicating Feature Importance
plt.figure(figsize=(16,20))
plt.barh(y=dset['attr'], width=dset['importance'], color='#1976D2')
plt.title('RFECV - Feature Importances', fontsize=20, fontweight='bold', pad=20)
plt.xlabel('Importance', fontsize=14, labelpad=20)
plt.show()

# %%
#Training the Random Forest Classifer on Train data
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier(n_estimators = 100, criterion = 'entropy', random_state = 0)
classifier.fit(X_opt, y_train)
# Out:
# RandomForestClassifier(criterion='entropy', random_state=0)

# %%
#Predicting the target variable
y_pred = classifier.predict(X_test)

# %%
#Confusion Matrix
from sklearn.metrics import confusion_matrix 
cm = confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[21,  0,  0],
#        [ 0, 42,  0],
#        [ 0,  0, 26]], dtype=int64)

# %%
#Classification Report
from sklearn.metrics import classification_report
cr = classification_report(y_test,y_pred)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#          AVG       1.00      1.00      1.00        21
#         FLOP       1.00      1.00      1.00        42
#          HIT       1.00      1.00      1.00        26
#
#     accuracy                           1.00        89
#    macro avg       1.00      1.00      1.00        89
# weighted avg       1.00      1.00      1.00        89

# %%
import pydot
# Pull out one tree from the forest
Tree = clf_rf.estimators_[5]
# Export the image to a dot file
from sklearn import tree
plt.figure(figsize=(25,15))
tree.plot_tree(Tree,filled=True, 
              rounded=True, 
              fontsize=14);

# %%
pip install pydot
# Out:
# Collecting pydot
#   Downloading pydot-1.4.2-py2.py3-none-any.whl (21 kB)
# Requirement already satisfied: pyparsing>=2.1.4 in c:\users\raora\anaconda3\lib\site-packages (from pydot) (2.4.7)
# Installing collected packages: pydot
# Successfully installed pydot-1.4.2
# Note: you may need to restart the kernel to use updated packages.
